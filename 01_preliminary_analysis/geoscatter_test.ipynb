# %%
# import plotly.graph_objects as go
# import plotly.express as px

# df = px.data.gapminder().query("year == 2007")
# fig = px.scatter_geo(df, lat =, lon =
#                      size="pop", # size of markers, "pop" is one of the columns of gapminder
#                      )
# fig.show()

# %%
# import plotly.graph_objects as go

# fig = go.Figure(go.Scattergeo())
# fig.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
# fig.show()

# %%
import plotly.express as px
import geopandas as gpd
import pandas as pd
# https://medium.com/analytics-vidhya/plotly-for-geomaps-bb75d1de189f

locations = pd.read_csv('csv/Locations.csv')
gdf = gpd.GeoDataFrame(
    locations, geometry = gpd.points_from_xy(locations.Longitude, locations.Latitude))

fig = px.scatter_mapbox(gdf,
                    lat = gdf.geometry.y,
                    lon = gdf.geometry.x,
                    hover_name="Location name",
                    zoom = 10,
                    )

fig.update_layout(mapbox_style="open-street-map")
# fig.update_layout(
#     mapbox_style="white-bg",
#     mapbox_layers=[
#         {
            
#             "below": 'traces',
#             "sourcetype": "raster",
#             "sourceattribution": "United States Geological Survey",
#             "source": [
# #                 "https://basemap.nationalmap.gov/arcgis/rest/services/USGSImageryOnly/MapServer/tile/{z}/{y}/{x}"
#                 'https://basemap.nationalmap.gov/arcgis/rest/services/USGSHydroCached/MapServer/tile/{z}/{y}/{x}'
#             ]
#         }
#       ])

fig.show()

# %%
px.set_mapbox_access_token(open("../.mapbox_token").read())

gdf = gpd.GeoDataFrame(
    locations, geometry = gpd.points_from_xy(locations.Longitude, locations.Latitude))

fig = px.scatter_mapbox(gdf,
                    lat = gdf.geometry.y,
                    lon = gdf.geometry.x,
                    hover_name="Location name",
                    zoom = 10,
                    )

fig.update_layout(mapbox_style = 
#                   "open-street-map",
#                   "stamen-terrain",
                  'satellite'
                 )
fig.show()

# %%
locations
# Out:
#    Location name  New  Latitude  Longitude      Type  Elevation  \
# 0      E100 edge  yes   4.68392  117.58604  Transect        379
# 1       D100 641  yes   4.71129  117.58753  Transect        479
# 2        C10 621  yes   4.71118  117.61899  Transect        403
# 3            B10  yes   4.72747  117.61433  Transect        352
# 4         E1 648  yes   4.69372  117.58118  Transect        428
# 5       D Matrix  yes   4.70272  117.59141  Transect        407
# 6       C Matrix  yes   4.71011  117.61071  Transect        271
# 7     Riparian 1  yes   4.65041  117.54203  Transect         80
# 8     Riparian 2  yes   4.65278  117.54653  Transect        172
# 9          VJR 1  yes   4.66443  117.53513  Transect        312
# 10         VJR 2  yes   4.66803  117.53897  Transect        391
# 11        B1 602  yes   4.72834  117.62350  Transect        326
# 12       OP3 843  yes   4.64005  117.45265  Transect        325
# 13     OP Belian  yes   4.63707  117.52016  Transect        282
# 14       LFE 703  yes   4.72441  117.59713  Transect        416
# 15       LFE 705  yes   4.72792  117.59558  Transect        461
# 16  B matrix 599  yes   4.72567  117.61924  Transect        312
# 17        D1 634  yes   4.71586  117.58414  Transect        425
# 18       D10 639  yes   4.70556  117.58361  Transect        323
# 19      D100 643  yes   4.71161  117.59318  Transect        337
# 20  E Matrix 647  yes   4.69588  117.57704  Transect        463
# 21        E1 651  yes   4.69891  117.58263  Transect        465
# 22       E10 654  yes   4.69128  117.57580  Transect        400
# 23      E100 658  yes   4.68914  117.58446  Transect        403
# 24     LFE river  yes   4.72500  117.59788  Transect        429
# 25            B1  yes   4.72834  117.62350  Transect        326
#
#                              ET before arrival  \
# 0              30 minutes drive, 1.5 hour walk
# 1            20 minutes drive, 30 minutes walk
# 2            15 minutes drive, 45 minutes walk
# 3   takes only 30min to get there (walk + car)
# 4            30 minutes drive, 30 minutes walk
# 5            20 minutes drive, 10 minutes walk
# 6            10 minutes drive, 20 minutes walk
# 7                 1 hour drive, 5 minutes walk
# 8                1 hour drive, 30 minutes walk
# 9                   1 hour drive, 2 hours walk
# 10                1 hour drive, 2.5 hours walk
# 11               10 minutes drive, 1 hour walk
# 12                                         NaN
# 13                                         NaN
# 14                             15 minutes walk
# 15                             30 minutes walk
# 16           10 minutes drive, 30 minutes walk
# 17           20 minutes drive, 45 minutes walk
# 18           20 minutes drive, 30 minutes walk
# 19           20 minutes drive, 30 minutes walk
# 20               30 minutes drive, 1 hour walk
# 21           30 minutes drive, 40 minutes walk
# 22               30 minutes drive, 1 hour walk
# 23               30 minutes drive, 1 hour walk
# 24                             10 minutes walk
# 25               10 minutes drive, 1 hour walk
#
#                                                 Notes  \
# 0                                   covered by leaves
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Not really inside the official SAFE matrix, se...
# 6   Semi-permanent marsh nearby (appx. 7 m from re...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                    planted in 2012
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
#
#                      geometry
# 0   POINT (117.58604 4.68392)
# 1   POINT (117.58753 4.71129)
# 2   POINT (117.61899 4.71118)
# 3   POINT (117.61433 4.72747)
# 4   POINT (117.58118 4.69372)
# 5   POINT (117.59141 4.70272)
# 6   POINT (117.61071 4.71011)
# 7   POINT (117.54203 4.65041)
# 8   POINT (117.54653 4.65278)
# 9   POINT (117.53513 4.66443)
# 10  POINT (117.53897 4.66803)
# 11  POINT (117.62350 4.72834)
# 12  POINT (117.45265 4.64005)
# 13  POINT (117.52016 4.63707)
# 14  POINT (117.59713 4.72441)
# 15  POINT (117.59558 4.72792)
# 16  POINT (117.61924 4.72567)
# 17  POINT (117.58414 4.71586)
# 18  POINT (117.58361 4.70556)
# 19  POINT (117.59318 4.71161)
# 20  POINT (117.57704 4.69588)
# 21  POINT (117.58263 4.69891)
# 22  POINT (117.57580 4.69128)
# 23  POINT (117.58446 4.68914)
# 24  POINT (117.59788 4.72500)
# 25  POINT (117.62350 4.72834)
